# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/Capstone/BigBasket Products.csv")
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
# Check data types of each column
df.info()

# Display basic statistics for numeric columns
df.describe()

# Display basic statistics for categorical columns
df.describe(include=['object'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27555 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18929 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB
#                              product          category sub_category   brand  \
# count                          27554             27555        27555   27554
# unique                         23540                11           90    2313
# ...

# %%
# Check for missing values
missing_values = df.isnull().sum()

# Display columns with missing values
missing_values[missing_values > 0]
# Out:
# product           1
# brand             1
# rating         8626
# description     115
# dtype: int64

# %%
# Numeric columns statistics
numeric_stats = df.describe()

# Categorical columns statistics
categorical_stats = df.describe(include=['object'])

numeric_stats, categorical_stats
# Out:
# (             index    sale_price  market_price        rating
#  count  27555.00000  27555.000000  27555.000000  18929.000000
#  mean   13778.00000    322.514808    382.056664      3.943410
#  std     7954.58767    486.263116    581.730717      0.739063
#  min        1.00000      2.450000      3.000000      1.000000
#  25%     6889.50000     95.000000    100.000000      3.700000
#  50%    13778.00000    190.000000    220.000000      4.100000
#  75%    20666.50000    359.000000    425.000000      4.300000
#  max    27555.00000  12500.000000  12500.000000      5.000000,
#                               product          category sub_category   brand  \
#  count                          27554             27555        27555   27554
#  unique                         23540                11           90    2313
#  top     Turmeric Powder/Arisina Pudi  Beauty & Hygiene    Skin Care  Fresho
#  freq                              26              7867         2294     638
#
# ...

# %%
def find_outliers_iqr(df):
    outliers = {}
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[column] = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers

# Find outliers in the dataset
outliers = find_outliers_iqr(df)

# Print outliers
for column, outlier_values in outliers.items():
    if not outlier_values.empty:
        print(f"Outliers in {column}:\n{outlier_values}\n")
    else:
        print(f"No outliers in {column}\n")
# Out:
# No outliers in index
#
# Outliers in sale_price:
# 8        1098.00
# 47        799.00
# 51        850.00
# 69        840.00
# 91        864.50
#           ...
# 27498    1071.00
# 27505     875.00
# 27514    1615.50
# 27538    4500.00
# 27542    1525.75
# Name: sale_price, Length: 2201, dtype: float64
#
# Outliers in market_price:
# 8        1098.0
# 34        969.0
# 96       1200.0
# 99       1398.0
# 118       999.0
#           ...
# 27488     980.0
# 27498    1071.0
# 27514    1795.0
# 27538    4500.0
# 27542    1795.0
# Name: market_price, Length: 2147, dtype: float64
#
# Outliers in rating:
# 1        2.3
# 11       2.2
# 29       1.5
# 43       2.6
# 64       1.0
#         ...
# 27415    2.0
# 27493    2.8
# 27498    2.0
# 27503    2.7
# 27518    1.0
# Name: rating, Length: 1312, dtype: float64

# %%
# !pip install uvicorn
# !pip install python-multipart
# !pip install kaleido
# !pip install fastapi
# !pip install pydantic
# !pip install PyYAML
# !pip install jinja2
# !pip install visions
# !pip install htmlmin
# !pip install phik
# !pip install requests
# !pip install tqdm
# !pip install seaborn
# !pip install multimethod
# !pip install statsmodels
# !pip install typeguard
# !pip install imagehash
# !pip install wordcloud
# !pip install dacite
# !pip install numba

import sys
# !{sys.executable} -m pip install -U ydata-profiling
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.4/62.4 kB 2.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.0/92.0 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.9/71.9 kB 5.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.5/142.5 kB 8.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 7.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.4/341.4 kB 14.8 MB/s eta 0:00:00
# ...

# %%
# Step 2: Load and Verify the Dataset
import pandas as pd

# Clean the column names by stripping any leading/trailing whitespace
df.columns = df.columns.str.strip()

# Expected columns
expected_columns = ['index', 'product', 'category', 'sub_category', 'brand', 'sale_price', 'market_price', 'type', 'rating', 'description']

# Verify that the dataset contains all the expected columns
assert all(column in df.columns for column in expected_columns), "Dataset does not contain the required columns."

# Print the cleaned column names to verify
print("Cleaned Columns in the dataset:", df.columns.tolist())

# Display the first few rows of the cleaned dataset to verify
print(df.head())

# Step 3: Generate the Profiling Report
from ydata_profiling import ProfileReport

# Create the profile report
profile = ProfileReport(df, title="Product Dataset Profiling Report", explorative=True)

# To display the report in a Jupyter Notebook
profile.to_notebook_iframe()

# Alternatively, to save the report to an HTML file
profile.to_file("product_dataset_report.html")
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# Checking for missing values again to confirm the columns and counts
missing_values = df.isnull().sum()
missing_values[missing_values > 0]

# Filling missing values for 'product' and 'brand' with mode
df['product'].fillna(df['product'].mode()[0], inplace=True)
df['brand'].fillna(df['brand'].mode()[0], inplace=True)

# Filling missing values for 'rating' with the mean
df['rating'].fillna(df['rating'].mean(), inplace=True)

# Filling missing values for 'description' with an empty string
df['description'].fillna('', inplace=True)

# Verify that there are no more missing values
df.isnull().sum()
# Out:
# index           0
# product         0
# category        0
# sub_category    0
# brand           0
# sale_price      0
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
import pandas as pd

# Assuming the DataFrame df is already loaded

def find_outliers_iqr(df):
    outliers = {}
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        outliers[column] = df[(df[column] < lower_bound) | (df[column] > upper_bound)][column]
    return outliers

def fill_outliers_with_median(df):
    for column in df.select_dtypes(include=['float64', 'int64']).columns:
        Q1 = df[column].quantile(0.25)
        Q3 = df[column].quantile(0.75)
        IQR = Q3 - Q1
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR
        median_value = df[column].median()
        df[column] = df[column].apply(lambda x: median_value if x < lower_bound or x > upper_bound else x)
    return df


# Find outliers in the dataset
outliers = find_outliers_iqr(df)

# Print outliers
for column, outlier_values in outliers.items():
    if not outlier_values.empty:
        print(f"Outliers in {column}:\n{outlier_values}\n")
    else:
        print(f"No outliers in {column}\n")

# Print the dataframe before filling outliers
print("DataFrame before filling outliers:")
print(df.describe())

# Fill outliers with median
df_filled = fill_outliers_with_median(df)

# Print the dataframe after filling outliers
print("DataFrame after filling outliers:")
print(df_filled.describe())

# Verify that outliers are filled
outliers_filled = find_outliers_iqr(df_filled)
for column, outlier_values in outliers_filled.items():
    if not outlier_values.empty:
        print(f"Outliers in {column} after filling:\n{outlier_values}\n")
    else:
        print(f"No outliers in {column} after filling\n")
# Out:
# No outliers in index
#
# Outliers in sale_price:
# 11       600.0
# 25       659.0
# 86       695.7
# 149      639.0
# 173      699.0
#          ...
# 27342    718.4
# 27415    700.0
# 27442    636.0
# 27468    650.0
# 27470    650.0
# Name: sale_price, Length: 1079, dtype: float64
#
# Outliers in market_price:
# 25       895.0
# 47       799.0
# 51       850.0
# 69       840.0
# 86       773.0
#          ...
# 27423    900.0
# 27442    795.0
# 27474    799.0
# 27485    725.0
# 27505    875.0
# Name: market_price, Length: 986, dtype: float64
#
# Outliers in rating:
# 12       5.0
# 16       5.0
# 17       4.9
# 24       5.0
# 30       2.9
#         ...
# 27508    5.0
# 27512    5.0
# 27515    5.0
# 27533    3.2
# 27548    5.0
# Name: rating, Length: 2567, dtype: float64
#
# DataFrame before filling outliers:
#              index    sale_price  market_price        rating
# count  27555.00000  27555.000000  27555.000000  18929.000000
# ...
